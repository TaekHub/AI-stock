# %%
pip install tensorflow pandas numpy yfinance scikit-learn matplotlib ta-lib sqlalchemy pymysql
# Out:
# Requirement already satisfied: tensorflow in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (2.18.0)
# Requirement already satisfied: pandas in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (1.26.0)
# Requirement already satisfied: yfinance in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (0.2.54)
# Requirement already satisfied: scikit-learn in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (3.10.0)
# Requirement already satisfied: ta-lib in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (0.4.28)
# Requirement already satisfied: sqlalchemy in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (2.0.38)
# Requirement already satisfied: pymysql in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (1.1.1)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install TA_Lib-0.4.28-cp311-cp311-win_amd64.whl
# Out:
# Processing c:\users\dmlxo\documents\github\ai-stock\models\ta_lib-0.4.28-cp311-cp311-win_amd64.whlNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\dmlxo\appdata\local\programs\python\python311\lib\site-packages (from TA-Lib==0.4.28) (1.26.0)
# TA-Lib is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import talib
import matplotlib.pyplot as plt

# 티커 설정
ticker = "TSLA"

# 데이터 수집 (기간 조정 가능)
df = yf.download(ticker, start="2024-03-17", end="2025-03-17", interval="1d")

# 기본 컬럼 선택
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# 데이터를 np.float64 자료형의 1D numpy 배열로 변환
close = np.array(df['Close'], dtype=np.float64).ravel()
high = np.array(df['High'], dtype=np.float64).ravel()
low = np.array(df['Low'], dtype=np.float64).ravel()
volume = np.array(df['Volume'], dtype=np.float64).ravel()

# 각종 기술적 지표 계산
rsi = talib.RSI(close, timeperiod=14)
macd, macd_signal, macd_hist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)
slowk, slowd = talib.STOCH(high, low, close, fastk_period=14, slowk_period=3, slowd_period=3)
cci = talib.CCI(high, low, close, timeperiod=14)
mfi = talib.MFI(high, low, close, volume, timeperiod=14)
adx = talib.ADX(high, low, close, timeperiod=14)
sma = talib.SMA(close, timeperiod=14)
ema = talib.EMA(close, timeperiod=14)
wma = talib.WMA(close, timeperiod=14)
upperband, middleband, lowerband = talib.BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
sar = talib.SAR(high, low, acceleration=0.02, maximum=0.2)
atr = talib.ATR(high, low, close, timeperiod=14)
natr = talib.NATR(high, low, close, timeperiod=14)
trange = talib.TRANGE(high, low, close)
obv = talib.OBV(close, volume)
ad = talib.AD(high, low, close, volume)
adosc = talib.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10)

# 지표들을 DataFrame에 추가
ind = pd.DataFrame({
    'RSI': rsi,
    'MACD': macd,
    'MACD_Signal': macd_signal,
    'MACD_Hist': macd_hist,
    '%K': slowk,
    '%D': slowd,
    'CCI': cci,
    'MFI': mfi,
    'ADX': adx,
    'SMA': sma,
    'EMA': ema,
    'WMA': wma,
    'UpperBand': upperband,
    'MiddleBand': middleband,
    'LowerBand': lowerband,
    'SAR': sar,
    'ATR': atr,
    'NATR': natr,
    'TRANGE': trange,
    'OBV': obv,
    'AD': ad,
    'ADOSC': adosc
}, index=df.index)

# NaN 값 제거
ind.dropna(inplace=True)

# 그래프 출력 함수 정의
def plot_indicator(ax, data, title, color='blue', additional_data=None, additional_color='red', bar_data=None):
    ax.plot(data, label=title, color=color)
    if additional_data is not None:
        ax.plot(additional_data, label=f'{title} Signal', color=additional_color)
    if bar_data is not None:
        ax.bar(data.index, bar_data, label=f'{title} Histogram', color='green', alpha=0.3)
    ax.set_title(title)
    ax.legend()

# 전체 그래프 생성
fig, axes = plt.subplots(nrows=17, ncols=1, figsize=(10, 85))

plot_indicator(axes[0], ind['RSI'], 'RSI')
plot_indicator(axes[1], ind['MACD'], 'MACD', additional_data=ind['MACD_Signal'], bar_data=ind['MACD_Hist'])
plot_indicator(axes[2], ind['%K'], 'Stochastic Oscillator', additional_data=ind['%D'])
plot_indicator(axes[3], ind['CCI'], 'CCI')
plot_indicator(axes[4], ind['MFI'], 'MFI')
plot_indicator(axes[5], ind['ADX'], 'ADX')
plot_indicator(axes[6], ind['SMA'], 'SMA')
plot_indicator(axes[7], ind['EMA'], 'EMA')
plot_indicator(axes[8], ind['WMA'], 'WMA')

# Bollinger Bands
axes[9].plot(ind['MiddleBand'], label='Middle Band', color='blue')
axes[9].plot(ind['UpperBand'], label='Upper Band', color='green')
axes[9].plot(ind['LowerBand'], label='Lower Band', color='red')
axes[9].set_title('Bollinger Bands')
axes[9].legend()

plot_indicator(axes[10], ind['SAR'], 'Parabolic SAR')
plot_indicator(axes[11], ind['ATR'], 'ATR')
plot_indicator(axes[12], ind['NATR'], 'NATR')
plot_indicator(axes[13], ind['TRANGE'], 'TRANGE')
plot_indicator(axes[14], ind['OBV'], 'OBV')
plot_indicator(axes[15], ind['AD'], 'AD')
plot_indicator(axes[16], ind['ADOSC'], 'ADOSC')

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import talib
import matplotlib.pyplot as plt

# 티커 설정 (예: AAPL)
ticker = "MSTX"

# 데이터 수집 (기간은 필요에 따라 조정)
df = yf.download(ticker, start="2024-03-17", end="2025-03-17", interval="1d")

# 기본 컬럼 선택
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# 데이터를 np.float64 자료형의 1D numpy 배열로 변환
close = np.array(df['Close'], dtype=np.float64).ravel()
high = np.array(df['High'], dtype=np.float64).ravel()
low = np.array(df['Low'], dtype=np.float64).ravel()
volume = np.array(df['Volume'], dtype=np.float64).ravel()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# 각종 기술적 지표 계산
rsi = talib.RSI(close, timeperiod=14)
macd, macd_signal, macd_hist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)
slowk, slowd = talib.STOCH(high, low, close, fastk_period=14, slowk_period=3, slowd_period=3)
cci = talib.CCI(high, low, close, timeperiod=14)
mfi = talib.MFI(high, low, close, volume, timeperiod=14)
adx = talib.ADX(high, low, close, timeperiod=14)
sma = talib.SMA(close, timeperiod=14)
ema = talib.EMA(close, timeperiod=14)
wma = talib.WMA(close, timeperiod=14)
upperband, middleband, lowerband = talib.BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
sar = talib.SAR(high, low, acceleration=0.02, maximum=0.2)
atr = talib.ATR(high, low, close, timeperiod=14)
natr = talib.NATR(high, low, close, timeperiod=14)
trange = talib.TRANGE(high, low, close)
obv = talib.OBV(close, volume)
ad = talib.AD(high, low, close, volume)
adosc = talib.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10)

# %%
# 지표들을 DataFrame에 추가 (원본 df의 인덱스를 사용)
ind = pd.DataFrame({
    'RSI': rsi,
    'MACD': macd,
    'MACD_Signal': macd_signal,
    'MACD_Hist': macd_hist,
    '%K': slowk,
    '%D': slowd,
    'CCI': cci,
    'MFI': mfi,
    'ADX': adx,
    'SMA': sma,
    'EMA': ema,
    'WMA': wma,
    'UpperBand': upperband,
    'MiddleBand': middleband,
    'LowerBand': lowerband,
    'SAR': sar,
    'ATR': atr,
    'NATR': natr,
    'TRANGE': trange,
    'OBV': obv,
    'AD': ad,
    'ADOSC': adosc
}, index=df.index)

# %%
import matplotlib.pyplot as plt

# 초기 지표 계산으로 인한 NaN 값 제거
ind.dropna(inplace=True)

# 서브플롯 생성 (17개의 개별 그래프, 하나의 열에 배치)
fig, axes = plt.subplots(17, 1, figsize=(10, 85))

# 각 지표 시각화
def plot_indicator(ax, data, title, color='blue', second_data=None, second_label=None, bar_data=None):
    ax.plot(data, label=title, color=color)
    if second_data is not None:
        ax.plot(second_data, label=second_label, color='red')
    if bar_data is not None:
        ax.bar(data.index, bar_data, label='Histogram', color='green', alpha=0.3)
    ax.set_title(title)
    ax.legend()

# 그래프 배치
plot_indicator(axes[0], ind['RSI'], 'RSI')
plot_indicator(axes[1], ind['MACD'], 'MACD', second_data=ind['MACD_Signal'], second_label='MACD Signal', bar_data=ind['MACD_Hist'])
plot_indicator(axes[2], ind['%K'], 'Stochastic %K', second_data=ind['%D'], second_label='%D')
plot_indicator(axes[3], ind['CCI'], 'CCI')
plot_indicator(axes[4], ind['MFI'], 'MFI')
plot_indicator(axes[5], ind['ADX'], 'ADX')
plot_indicator(axes[6], ind['SMA'], 'SMA')
plot_indicator(axes[7], ind['EMA'], 'EMA')
plot_indicator(axes[8], ind['WMA'], 'WMA')
plot_indicator(axes[9], ind['MiddleBand'], 'Bollinger Bands', second_data=ind['UpperBand'], second_label='Upper Band')
axes[9].plot(ind['LowerBand'], label='Lower Band', color='red')
axes[9].legend()
plot_indicator(axes[10], ind['SAR'], 'Parabolic SAR')
plot_indicator(axes[11], ind['ATR'], 'ATR')
plot_indicator(axes[12], ind['NATR'], 'NATR')
plot_indicator(axes[13], ind['TRANGE'], 'TRANGE')
plot_indicator(axes[14], ind['OBV'], 'OBV')
plot_indicator(axes[15], ind['AD'], 'AD')
plot_indicator(axes[16], ind['ADOSC'], 'ADOSC')

# 레이아웃 조정
plt.tight_layout()
plt.show()

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import talib
import matplotlib.pyplot as plt

# 티커 설정 (예: AAPL)
ticker = "MSTX"

# 데이터 수집 (기간은 필요에 따라 조정)
df = yf.download(ticker, start="2024-03-17", end="2025-03-17", interval="1d")

# 기본 컬럼 선택
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# 데이터를 np.float64 자료형의 1D numpy 배열로 변환
close = np.array(df['Close'], dtype=np.float64).ravel()
high = np.array(df['High'], dtype=np.float64).ravel()
low = np.array(df['Low'], dtype=np.float64).ravel()
volume = np.array(df['Volume'], dtype=np.float64).ravel()

# 각종 기술적 지표 계산
rsi = talib.RSI(close, timeperiod=14)
macd, macd_signal, macd_hist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)
slowk, slowd = talib.STOCH(high, low, close, fastk_period=14, slowk_period=3, slowd_period=3)
cci = talib.CCI(high, low, close, timeperiod=14)
mfi = talib.MFI(high, low, close, volume, timeperiod=14)
adx = talib.ADX(high, low, close, timeperiod=14)
sma = talib.SMA(close, timeperiod=14)
ema = talib.EMA(close, timeperiod=14)
wma = talib.WMA(close, timeperiod=14)
upperband, middleband, lowerband = talib.BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
sar = talib.SAR(high, low, acceleration=0.02, maximum=0.2)
atr = talib.ATR(high, low, close, timeperiod=14)
natr = talib.NATR(high, low, close, timeperiod=14)
trange = talib.TRANGE(high, low, close)
obv = talib.OBV(close, volume)
ad = talib.AD(high, low, close, volume)
adosc = talib.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10)

# 지표들을 DataFrame에 추가 (원본 df의 인덱스를 사용)
ind = pd.DataFrame({
    'RSI': rsi,
    'MACD': macd,
    'MACD_Signal': macd_signal,
    'MACD_Hist': macd_hist,
    '%K': slowk,
    '%D': slowd,
    'CCI': cci,
    'MFI': mfi,
    'ADX': adx,
    'SMA': sma,
    'EMA': ema,
    'WMA': wma,
    'UpperBand': upperband,
    'MiddleBand': middleband,
    'LowerBand': lowerband,
    'SAR': sar,
    'ATR': atr,
    'NATR': natr,
    'TRANGE': trange,
    'OBV': obv,
    'AD': ad,
    'ADOSC': adosc
}, index=df.index)

# 초기 지표 계산으로 인한 NaN 값 제거
ind.dropna(inplace=True)

# 시각화: 6행 3열 서브플롯으로 각 지표 출력
plt.figure(figsize=(100, 16))

# RSI
plt.subplot(6, 3, 1)
plt.plot(ind['RSI'], label='RSI', color='blue')
plt.title('RSI')
plt.legend()

# MACD
plt.subplot(6, 3, 2)
plt.plot(ind['MACD'], label='MACD', color='blue')
plt.plot(ind['MACD_Signal'], label='MACD Signal', color='red')
plt.bar(ind.index, ind['MACD_Hist'], label='MACD Histogram', color='green', alpha=0.3)
plt.title('MACD')
plt.legend()

# Stochastic Oscillator
plt.subplot(6, 3, 3)
plt.plot(ind['%K'], label='%K', color='blue')
plt.plot(ind['%D'], label='%D', color='red')
plt.title('Stochastic Oscillator')
plt.legend()

# CCI
plt.subplot(6, 3, 4)
plt.plot(ind['CCI'], label='CCI', color='blue')
plt.title('CCI')
plt.legend()

# MFI
plt.subplot(6, 3, 5)
plt.plot(ind['MFI'], label='MFI', color='blue')
plt.title('MFI')
plt.legend()

# ADX
plt.subplot(6, 3, 6)
plt.plot(ind['ADX'], label='ADX', color='blue')
plt.title('ADX')
plt.legend()

# SMA
plt.subplot(6, 3, 7)
plt.plot(ind['SMA'], label='SMA', color='blue')
plt.title('SMA')
plt.legend()

# EMA
plt.subplot(6, 3, 8)
plt.plot(ind['EMA'], label='EMA', color='blue')
plt.title('EMA')
plt.legend()

# WMA
plt.subplot(6, 3, 9)
plt.plot(ind['WMA'], label='WMA', color='blue')
plt.title('WMA')
plt.legend()

# Bollinger Bands
plt.subplot(6, 3, 10)
plt.plot(ind['MiddleBand'], label='Middle Band', color='blue')
plt.plot(ind['UpperBand'], label='Upper Band', color='green')
plt.plot(ind['LowerBand'], label='Lower Band', color='red')
plt.title('Bollinger Bands')
plt.legend()

# Parabolic SAR
plt.subplot(6, 3, 11)
plt.plot(ind['SAR'], label='SAR', color='blue')
plt.title('Parabolic SAR')
plt.legend()

# ATR
plt.subplot(6, 3, 12)
plt.plot(ind['ATR'], label='ATR', color='blue')
plt.title('ATR')
plt.legend()

# NATR
plt.subplot(6, 3, 13)
plt.plot(ind['NATR'], label='NATR', color='blue')
plt.title('NATR')
plt.legend()

# TRANGE
plt.subplot(6, 3, 14)
plt.plot(ind['TRANGE'], label='TRANGE', color='blue')
plt.title('TRANGE')
plt.legend()

# OBV
plt.subplot(6, 3, 15)
plt.plot(ind['OBV'], label='OBV', color='blue')
plt.title('OBV')
plt.legend()

# AD
plt.subplot(6, 3, 16)
plt.plot(ind['AD'], label='AD', color='blue')
plt.title('AD')
plt.legend()

# ADOSC
plt.subplot(6, 3, 17)
plt.plot(ind['ADOSC'], label='ADOSC', color='blue')
plt.title('ADOSC')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(df.tail())
# Out:
# Price            Open       High        Low      Close    Volume
# Ticker           MSTX       MSTX       MSTX       MSTX      MSTX
# Date
# 2025-03-10  24.799999  25.600000  17.900000  19.270000  24326800
# 2025-03-11  20.110001  22.920000  17.990000  22.459999  17093200
# 2025-03-12  23.290001  24.100000  20.360001  22.850000  14893100
# 2025-03-13  22.690001  24.177000  21.299999  22.920000   9380100
# 2025-03-14  24.580000  28.950001  24.480000  28.709999  14142000

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import talib
import matplotlib.pyplot as plt

# 📌 1. 주가 데이터 가져오기
ticker = "TSLA"
df = yf.download(ticker, start="2024-03-17", end="2024-03-17", interval="1d")

# 필요한 컬럼만 선택
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# 📌 2. numpy 배열로 변환
close = df['Close'].values.astype(float)
high = df['High'].values.astype(float)
low = df['Low'].values.astype(float)
volume = df['Volume'].values.astype(float)

# 📌 3. 기술적 지표 계산
rsi = talib.RSI(close, timeperiod=14)
macd, macd_signal, macd_hist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)
slowk, slowd = talib.STOCH(high, low, close, fastk_period=14, slowk_period=3, slowd_period=3)
cci = talib.CCI(high, low, close, timeperiod=14)
mfi = talib.MFI(high, low, close, volume, timeperiod=14)
adx = talib.ADX(high, low, close, timeperiod=14)
sma = talib.SMA(close, timeperiod=14)
ema = talib.EMA(close, timeperiod=14)
wma = talib.WMA(close, timeperiod=14)
upperband, middleband, lowerband = talib.BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
sar = talib.SAR(high, low, acceleration=0.02, maximum=0.2)
atr = talib.ATR(high, low, close, timeperiod=14)
natr = talib.NATR(high, low, close, timeperiod=14)
trange = talib.TRANGE(high, low, close)
obv = talib.OBV(close, volume)
ad = talib.AD(high, low, close, volume)
adosc = talib.ADOSC(high, low, close, volume, fastperiod=3, slowperiod=10)

# 📌 4. 데이터프레임 생성 (NaN 값 제거)
indicators = pd.DataFrame({
    'RSI': rsi,
    'MACD': macd,
    'MACD Signal': macd_signal,
    'MACD Histogram': macd_hist,
    '%K': slowk,
    '%D': slowd,
    'CCI': cci,
    'MFI': mfi,
    'ADX': adx,
    'SMA': sma,
    'EMA': ema,
    'WMA': wma,
    'Upper Band': upperband,
    'Middle Band': middleband,
    'Lower Band': lowerband,
    'SAR': sar,
    'ATR': atr,
    'NATR': natr,
    'TRANGE': trange,
    'OBV': obv,
    'AD': ad,
    'ADOSC': adosc
}, index=df.index)

indicators.dropna(inplace=True)  # NaN 값 제거

# 📌 5. 그래프 시각화
plt.figure(figsize=(20, 16))  # 🔥 폭을 20으로 확장하여 넓게 표시

# 🎯 1. 종가 (Close Price)
plt.subplot(4, 2, 1)
plt.plot(df.index, df['Close'], label="Close Price", color='black')
plt.title("Close Price")
plt.legend()

# 🎯 2. RSI (Relative Strength Index)
plt.subplot(4, 2, 2)
plt.plot(indicators.index, indicators['RSI'], label="RSI", color='purple')
plt.axhline(70, color='red', linestyle='--')  # 과매수선
plt.axhline(30, color='green', linestyle='--')  # 과매도선
plt.title("RSI (Relative Strength Index)")
plt.legend()

# 🎯 3. MACD
plt.subplot(4, 2, 3)
plt.plot(indicators.index, indicators['MACD'], label="MACD", color='blue')
plt.plot(indicators.index, indicators['MACD Signal'], label="MACD Signal", color='red')
plt.bar(indicators.index, indicators['MACD Histogram'], label="MACD Histogram", color='gray')
plt.title("MACD")
plt.legend()

# 🎯 4. Stochastic Oscillator (%K & %D)
plt.subplot(4, 2, 4)
plt.plot(indicators.index, indicators['%K'], label="%K", color='blue')
plt.plot(indicators.index, indicators['%D'], label="%D", color='orange')
plt.title("Stochastic Oscillator (%K, %D)")
plt.legend()

# 🎯 5. Bollinger Bands (볼린저 밴드)
plt.subplot(4, 2, 5)
plt.plot(df.index, df['Close'], label="Close Price", color='black')
plt.plot(indicators.index, indicators['Upper Band'], label="Upper Band", color='red')
plt.plot(indicators.index, indicators['Middle Band'], label="Middle Band", color='blue')
plt.plot(indicators.index, indicators['Lower Band'], label="Lower Band", color='green')
plt.title("Bollinger Bands")
plt.legend()

# 🎯 6. ADX (Average Directional Index)
plt.subplot(4, 2, 6)
plt.plot(indicators.index, indicators['ADX'], label="ADX", color='brown')
plt.title("ADX (Average Directional Index)")
plt.legend()

# 🎯 7. On-Balance Volume (OBV)
plt.subplot(4, 2, 7)
plt.plot(indicators.index, indicators['OBV'], label="OBV", color='magenta')
plt.title("On-Balance Volume (OBV)")
plt.legend()

# 🎯 8. ATR (Average True Range)
plt.subplot(4, 2, 8)
plt.plot(indicators.index, indicators['ATR'], label="ATR", color='teal')
plt.title("ATR (Average True Range)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-03-17 -> 2024-03-17)')
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 21
#      18 volume = df['Volume'].values.astype(float)
#      20 # 📌 3. 기술적 지표 계산
# ---> 21 rsi = talib.RSI(close, timeperiod=14)
#      22 macd, macd_signal, macd_hist = talib.MACD(close, fastperiod=12, slowperiod=26, signalperiod=9)
#      23 slowk, slowd = talib.STOCH(high, low, close, fastk_period=14, slowk_period=3, slowd_period=3)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\talib\__init__.py:64, in _wrapper.<locals>.wrapper(*args, **kwds)
#      61     _args = args
#      62     _kwds = kwds
# ---> 64 result = func(*_args, **_kwds)
#      66 # check to see if we got a streaming result
#      67 first_result = result[0] if isinstance(result, tuple) else result
#
# File talib/_func.pxi:4375, in talib._ta_lib.RSI()
#
# File talib/_func.pxi:24, in talib._ta_lib.check_array()
#
# Exception: input array has wrong dimensions
